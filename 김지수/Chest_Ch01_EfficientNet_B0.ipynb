# %% [markdown]
# <a href="https://colab.research.google.com/github/JJay1010/sw-team_project/blob/main/Chest_Ch01_EfficientNet_B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

x_data = np.load('/content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_x.npy')
y_data = np.load('/content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_y.npy')

# %%
# train/test 8:2 나누기

from sklearn.model_selection import train_test_split

x_train, x_temp, y_train, y_temp = train_test_split(x_data, y_data, test_size = 0.2, random_state=42)
x_test, x_valid, y_test, y_valid = train_test_split(x_temp, y_temp, test_size = 0.5, random_state=42)

# %%
from tensorflow.keras import applications
import tensorflow as tf

base_model = tf.keras.applications.efficientnet.EfficientNetB0(include_top=False, weights = 'imagenet')

base_model.trainable = False

base_model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling (Rescaling)          (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  normalization (Normalization)  (None, None, None,   7           ['rescaling[0][0]']
#                                 3)
#
#  tf.math.truediv (TFOpLambda)   (None, None, None,   0           ['normalization[0][0]']
#                                 3)
#
#  stem_conv_pad (ZeroPadding2D)  (None, None, None,   0           ['tf.math.truediv[0][0]']
#                                 3)
#
#  stem_conv (Conv2D)             (None, None, None,   864         ['stem_conv_pad[0][0]']
#                                 32)
#
#  stem_bn (BatchNormalization)   (None, None, None,   128         ['stem_conv[0][0]']
#                                 32)
#
#  stem_activation (Activation)   (None, None, None,   0           ['stem_bn[0][0]']
#                                 32)
#
#  block1a_dwconv (DepthwiseConv2  (None, None, None,   288        ['stem_activation[0][0]']
#  D)                             32)
#
#  block1a_bn (BatchNormalization  (None, None, None,   128        ['block1a_dwconv[0][0]']
#  )                              32)
#
#  block1a_activation (Activation  (None, None, None,   0          ['block1a_bn[0][0]']
#  )                              32)
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, None, None,   0           ['block1a_activation[0][0]',
#                                 32)                               'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, None, None,   512         ['block1a_se_excite[0][0]']
#                                 16)
#
#  block1a_project_bn (BatchNorma  (None, None, None,   64         ['block1a_project_conv[0][0]']
#  lization)                      16)
#
#  block2a_expand_conv (Conv2D)   (None, None, None,   1536        ['block1a_project_bn[0][0]']
#                                 96)
#
#  block2a_expand_bn (BatchNormal  (None, None, None,   384        ['block2a_expand_conv[0][0]']
#  ization)                       96)
#
#  block2a_expand_activation (Act  (None, None, None,   0          ['block2a_expand_bn[0][0]']
#  ivation)                       96)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block2a_expand_activation[0][0]
#  g2D)                           96)                              ']
#
#  block2a_dwconv (DepthwiseConv2  (None, None, None,   864        ['block2a_dwconv_pad[0][0]']
#  D)                             96)
#
#  block2a_bn (BatchNormalization  (None, None, None,   384        ['block2a_dwconv[0][0]']
#  )                              96)
#
#  block2a_activation (Activation  (None, None, None,   0          ['block2a_bn[0][0]']
#  )                              96)
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, None, None,   0           ['block2a_activation[0][0]',
#                                 96)                               'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, None, None,   2304        ['block2a_se_excite[0][0]']
#                                 24)
#
#  block2a_project_bn (BatchNorma  (None, None, None,   96         ['block2a_project_conv[0][0]']
#  lization)                      24)
#
#  block2b_expand_conv (Conv2D)   (None, None, None,   3456        ['block2a_project_bn[0][0]']
#                                 144)
#
#  block2b_expand_bn (BatchNormal  (None, None, None,   576        ['block2b_expand_conv[0][0]']
#  ization)                       144)
#
#  block2b_expand_activation (Act  (None, None, None,   0          ['block2b_expand_bn[0][0]']
#  ivation)                       144)
#
#  block2b_dwconv (DepthwiseConv2  (None, None, None,   1296       ['block2b_expand_activation[0][0]
#  D)                             144)                             ']
#
#  block2b_bn (BatchNormalization  (None, None, None,   576        ['block2b_dwconv[0][0]']
#  )                              144)
#
#  block2b_activation (Activation  (None, None, None,   0          ['block2b_bn[0][0]']
#  )                              144)
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, None, None,   0           ['block2b_activation[0][0]',
#                                 144)                              'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, None, None,   3456        ['block2b_se_excite[0][0]']
#                                 24)
#
#  block2b_project_bn (BatchNorma  (None, None, None,   96         ['block2b_project_conv[0][0]']
#  lization)                      24)
#
#  block2b_drop (Dropout)         (None, None, None,   0           ['block2b_project_bn[0][0]']
#                                 24)
#
#  block2b_add (Add)              (None, None, None,   0           ['block2b_drop[0][0]',
#                                 24)                               'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, None, None,   3456        ['block2b_add[0][0]']
#                                 144)
#
#  block3a_expand_bn (BatchNormal  (None, None, None,   576        ['block3a_expand_conv[0][0]']
#  ization)                       144)
#
#  block3a_expand_activation (Act  (None, None, None,   0          ['block3a_expand_bn[0][0]']
#  ivation)                       144)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block3a_expand_activation[0][0]
#  g2D)                           144)                             ']
#
#  block3a_dwconv (DepthwiseConv2  (None, None, None,   3600       ['block3a_dwconv_pad[0][0]']
#  D)                             144)
#
#  block3a_bn (BatchNormalization  (None, None, None,   576        ['block3a_dwconv[0][0]']
#  )                              144)
#
#  block3a_activation (Activation  (None, None, None,   0          ['block3a_bn[0][0]']
#  )                              144)
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, None, None,   0           ['block3a_activation[0][0]',
#                                 144)                              'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, None, None,   5760        ['block3a_se_excite[0][0]']
#                                 40)
#
#  block3a_project_bn (BatchNorma  (None, None, None,   160        ['block3a_project_conv[0][0]']
#  lization)                      40)
#
#  block3b_expand_conv (Conv2D)   (None, None, None,   9600        ['block3a_project_bn[0][0]']
#                                 240)
#
#  block3b_expand_bn (BatchNormal  (None, None, None,   960        ['block3b_expand_conv[0][0]']
#  ization)                       240)
#
#  block3b_expand_activation (Act  (None, None, None,   0          ['block3b_expand_bn[0][0]']
#  ivation)                       240)
#
#  block3b_dwconv (DepthwiseConv2  (None, None, None,   6000       ['block3b_expand_activation[0][0]
#  D)                             240)                             ']
#
#  block3b_bn (BatchNormalization  (None, None, None,   960        ['block3b_dwconv[0][0]']
#  )                              240)
#
#  block3b_activation (Activation  (None, None, None,   0          ['block3b_bn[0][0]']
#  )                              240)
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, None, None,   0           ['block3b_activation[0][0]',
#                                 240)                              'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, None, None,   9600        ['block3b_se_excite[0][0]']
#                                 40)
#
#  block3b_project_bn (BatchNorma  (None, None, None,   160        ['block3b_project_conv[0][0]']
#  lization)                      40)
#
#  block3b_drop (Dropout)         (None, None, None,   0           ['block3b_project_bn[0][0]']
#                                 40)
#
#  block3b_add (Add)              (None, None, None,   0           ['block3b_drop[0][0]',
#                                 40)                               'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, None, None,   9600        ['block3b_add[0][0]']
#                                 240)
#
#  block4a_expand_bn (BatchNormal  (None, None, None,   960        ['block4a_expand_conv[0][0]']
#  ization)                       240)
#
#  block4a_expand_activation (Act  (None, None, None,   0          ['block4a_expand_bn[0][0]']
#  ivation)                       240)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block4a_expand_activation[0][0]
#  g2D)                           240)                             ']
#
#  block4a_dwconv (DepthwiseConv2  (None, None, None,   2160       ['block4a_dwconv_pad[0][0]']
#  D)                             240)
#
#  block4a_bn (BatchNormalization  (None, None, None,   960        ['block4a_dwconv[0][0]']
#  )                              240)
#
#  block4a_activation (Activation  (None, None, None,   0          ['block4a_bn[0][0]']
#  )                              240)
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, None, None,   0           ['block4a_activation[0][0]',
#                                 240)                              'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, None, None,   19200       ['block4a_se_excite[0][0]']
#                                 80)
#
#  block4a_project_bn (BatchNorma  (None, None, None,   320        ['block4a_project_conv[0][0]']
#  lization)                      80)
#
#  block4b_expand_conv (Conv2D)   (None, None, None,   38400       ['block4a_project_bn[0][0]']
#                                 480)
#
#  block4b_expand_bn (BatchNormal  (None, None, None,   1920       ['block4b_expand_conv[0][0]']
#  ization)                       480)
#
#  block4b_expand_activation (Act  (None, None, None,   0          ['block4b_expand_bn[0][0]']
#  ivation)                       480)
#
#  block4b_dwconv (DepthwiseConv2  (None, None, None,   4320       ['block4b_expand_activation[0][0]
#  D)                             480)                             ']
#
#  block4b_bn (BatchNormalization  (None, None, None,   1920       ['block4b_dwconv[0][0]']
#  )                              480)
#
#  block4b_activation (Activation  (None, None, None,   0          ['block4b_bn[0][0]']
#  )                              480)
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, None, None,   0           ['block4b_activation[0][0]',
#                                 480)                              'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, None, None,   38400       ['block4b_se_excite[0][0]']
#                                 80)
#
#  block4b_project_bn (BatchNorma  (None, None, None,   320        ['block4b_project_conv[0][0]']
#  lization)                      80)
#
#  block4b_drop (Dropout)         (None, None, None,   0           ['block4b_project_bn[0][0]']
#                                 80)
#
#  block4b_add (Add)              (None, None, None,   0           ['block4b_drop[0][0]',
#                                 80)                               'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, None, None,   38400       ['block4b_add[0][0]']
#                                 480)
#
#  block4c_expand_bn (BatchNormal  (None, None, None,   1920       ['block4c_expand_conv[0][0]']
#  ization)                       480)
#
#  block4c_expand_activation (Act  (None, None, None,   0          ['block4c_expand_bn[0][0]']
#  ivation)                       480)
#
#  block4c_dwconv (DepthwiseConv2  (None, None, None,   4320       ['block4c_expand_activation[0][0]
#  D)                             480)                             ']
#
#  block4c_bn (BatchNormalization  (None, None, None,   1920       ['block4c_dwconv[0][0]']
#  )                              480)
#
#  block4c_activation (Activation  (None, None, None,   0          ['block4c_bn[0][0]']
#  )                              480)
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, None, None,   0           ['block4c_activation[0][0]',
#                                 480)                              'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, None, None,   38400       ['block4c_se_excite[0][0]']
#                                 80)
#
#  block4c_project_bn (BatchNorma  (None, None, None,   320        ['block4c_project_conv[0][0]']
#  lization)                      80)
#
#  block4c_drop (Dropout)         (None, None, None,   0           ['block4c_project_bn[0][0]']
#                                 80)
#
#  block4c_add (Add)              (None, None, None,   0           ['block4c_drop[0][0]',
#                                 80)                               'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, None, None,   38400       ['block4c_add[0][0]']
#                                 480)
#
#  block5a_expand_bn (BatchNormal  (None, None, None,   1920       ['block5a_expand_conv[0][0]']
#  ization)                       480)
#
#  block5a_expand_activation (Act  (None, None, None,   0          ['block5a_expand_bn[0][0]']
#  ivation)                       480)
#
#  block5a_dwconv (DepthwiseConv2  (None, None, None,   12000      ['block5a_expand_activation[0][0]
#  D)                             480)                             ']
#
#  block5a_bn (BatchNormalization  (None, None, None,   1920       ['block5a_dwconv[0][0]']
#  )                              480)
#
#  block5a_activation (Activation  (None, None, None,   0          ['block5a_bn[0][0]']
#  )                              480)
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, None, None,   0           ['block5a_activation[0][0]',
#                                 480)                              'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, None, None,   53760       ['block5a_se_excite[0][0]']
#                                 112)
#
#  block5a_project_bn (BatchNorma  (None, None, None,   448        ['block5a_project_conv[0][0]']
#  lization)                      112)
#
#  block5b_expand_conv (Conv2D)   (None, None, None,   75264       ['block5a_project_bn[0][0]']
#                                 672)
#
#  block5b_expand_bn (BatchNormal  (None, None, None,   2688       ['block5b_expand_conv[0][0]']
#  ization)                       672)
#
#  block5b_expand_activation (Act  (None, None, None,   0          ['block5b_expand_bn[0][0]']
#  ivation)                       672)
#
#  block5b_dwconv (DepthwiseConv2  (None, None, None,   16800      ['block5b_expand_activation[0][0]
#  D)                             672)                             ']
#
#  block5b_bn (BatchNormalization  (None, None, None,   2688       ['block5b_dwconv[0][0]']
#  )                              672)
#
#  block5b_activation (Activation  (None, None, None,   0          ['block5b_bn[0][0]']
#  )                              672)
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, None, None,   0           ['block5b_activation[0][0]',
#                                 672)                              'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, None, None,   75264       ['block5b_se_excite[0][0]']
#                                 112)
#
#  block5b_project_bn (BatchNorma  (None, None, None,   448        ['block5b_project_conv[0][0]']
#  lization)                      112)
#
#  block5b_drop (Dropout)         (None, None, None,   0           ['block5b_project_bn[0][0]']
#                                 112)
#
#  block5b_add (Add)              (None, None, None,   0           ['block5b_drop[0][0]',
#                                 112)                              'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, None, None,   75264       ['block5b_add[0][0]']
#                                 672)
#
#  block5c_expand_bn (BatchNormal  (None, None, None,   2688       ['block5c_expand_conv[0][0]']
#  ization)                       672)
#
#  block5c_expand_activation (Act  (None, None, None,   0          ['block5c_expand_bn[0][0]']
#  ivation)                       672)
#
#  block5c_dwconv (DepthwiseConv2  (None, None, None,   16800      ['block5c_expand_activation[0][0]
#  D)                             672)                             ']
#
#  block5c_bn (BatchNormalization  (None, None, None,   2688       ['block5c_dwconv[0][0]']
#  )                              672)
#
#  block5c_activation (Activation  (None, None, None,   0          ['block5c_bn[0][0]']
#  )                              672)
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, None, None,   0           ['block5c_activation[0][0]',
#                                 672)                              'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, None, None,   75264       ['block5c_se_excite[0][0]']
#                                 112)
#
#  block5c_project_bn (BatchNorma  (None, None, None,   448        ['block5c_project_conv[0][0]']
#  lization)                      112)
#
#  block5c_drop (Dropout)         (None, None, None,   0           ['block5c_project_bn[0][0]']
#                                 112)
#
#  block5c_add (Add)              (None, None, None,   0           ['block5c_drop[0][0]',
#                                 112)                              'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, None, None,   75264       ['block5c_add[0][0]']
#                                 672)
#
#  block6a_expand_bn (BatchNormal  (None, None, None,   2688       ['block6a_expand_conv[0][0]']
#  ization)                       672)
#
#  block6a_expand_activation (Act  (None, None, None,   0          ['block6a_expand_bn[0][0]']
#  ivation)                       672)
#
#  block6a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block6a_expand_activation[0][0]
#  g2D)                           672)                             ']
#
#  block6a_dwconv (DepthwiseConv2  (None, None, None,   16800      ['block6a_dwconv_pad[0][0]']
#  D)                             672)
#
#  block6a_bn (BatchNormalization  (None, None, None,   2688       ['block6a_dwconv[0][0]']
#  )                              672)
#
#  block6a_activation (Activation  (None, None, None,   0          ['block6a_bn[0][0]']
#  )                              672)
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
# ...
#  )                              1152)
#
#  block6b_activation (Activation  (None, None, None,   0          ['block6b_bn[0][0]']
#  )                              1152)
#
#  block6b_se_squeeze (GlobalAver  (None, 1152)        0           ['block6b_activation[0][0]']
#  agePooling2D)
#
#  block6b_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6b_se_squeeze[0][0]']
#
#  block6b_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multiply)   (None, None, None,   0           ['block6b_activation[0][0]',
#                                 1152)                             'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv2D)  (None, None, None,   221184      ['block6b_se_excite[0][0]']
#                                 192)
#
#  block6b_project_bn (BatchNorma  (None, None, None,   768        ['block6b_project_conv[0][0]']
#  lization)                      192)
#
#  block6b_drop (Dropout)         (None, None, None,   0           ['block6b_project_bn[0][0]']
#                                 192)
#
#  block6b_add (Add)              (None, None, None,   0           ['block6b_drop[0][0]',
#                                 192)                              'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, None, None,   221184      ['block6b_add[0][0]']
#                                 1152)
#
#  block6c_expand_bn (BatchNormal  (None, None, None,   4608       ['block6c_expand_conv[0][0]']
#  ization)                       1152)
#
#  block6c_expand_activation (Act  (None, None, None,   0          ['block6c_expand_bn[0][0]']
#  ivation)                       1152)
#
#  block6c_dwconv (DepthwiseConv2  (None, None, None,   28800      ['block6c_expand_activation[0][0]
#  D)                             1152)                            ']
#
#  block6c_bn (BatchNormalization  (None, None, None,   4608       ['block6c_dwconv[0][0]']
#  )                              1152)
#
#  block6c_activation (Activation  (None, None, None,   0          ['block6c_bn[0][0]']
#  )                              1152)
#
#  block6c_se_squeeze (GlobalAver  (None, 1152)        0           ['block6c_activation[0][0]']
#  agePooling2D)
#
#  block6c_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6c_se_squeeze[0][0]']
#
#  block6c_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multiply)   (None, None, None,   0           ['block6c_activation[0][0]',
#                                 1152)                             'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv2D)  (None, None, None,   221184      ['block6c_se_excite[0][0]']
#                                 192)
#
#  block6c_project_bn (BatchNorma  (None, None, None,   768        ['block6c_project_conv[0][0]']
#  lization)                      192)
#
#  block6c_drop (Dropout)         (None, None, None,   0           ['block6c_project_bn[0][0]']
#                                 192)
#
#  block6c_add (Add)              (None, None, None,   0           ['block6c_drop[0][0]',
#                                 192)                              'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2D)   (None, None, None,   221184      ['block6c_add[0][0]']
#                                 1152)
#
#  block6d_expand_bn (BatchNormal  (None, None, None,   4608       ['block6d_expand_conv[0][0]']
#  ization)                       1152)
#
#  block6d_expand_activation (Act  (None, None, None,   0          ['block6d_expand_bn[0][0]']
#  ivation)                       1152)
#
#  block6d_dwconv (DepthwiseConv2  (None, None, None,   28800      ['block6d_expand_activation[0][0]
#  D)                             1152)                            ']
#
#  block6d_bn (BatchNormalization  (None, None, None,   4608       ['block6d_dwconv[0][0]']
#  )                              1152)
#
#  block6d_activation (Activation  (None, None, None,   0          ['block6d_bn[0][0]']
#  )                              1152)
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, None, None,   0           ['block6d_activation[0][0]',
#                                 1152)                             'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, None, None,   221184      ['block6d_se_excite[0][0]']
#                                 192)
#
#  block6d_project_bn (BatchNorma  (None, None, None,   768        ['block6d_project_conv[0][0]']
#  lization)                      192)
#
#  block6d_drop (Dropout)         (None, None, None,   0           ['block6d_project_bn[0][0]']
#                                 192)
#
#  block6d_add (Add)              (None, None, None,   0           ['block6d_drop[0][0]',
#                                 192)                              'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, None, None,   221184      ['block6d_add[0][0]']
#                                 1152)
#
#  block7a_expand_bn (BatchNormal  (None, None, None,   4608       ['block7a_expand_conv[0][0]']
#  ization)                       1152)
#
#  block7a_expand_activation (Act  (None, None, None,   0          ['block7a_expand_bn[0][0]']
#  ivation)                       1152)
#
#  block7a_dwconv (DepthwiseConv2  (None, None, None,   10368      ['block7a_expand_activation[0][0]
#  D)                             1152)                            ']
#
#  block7a_bn (BatchNormalization  (None, None, None,   4608       ['block7a_dwconv[0][0]']
#  )                              1152)
#
#  block7a_activation (Activation  (None, None, None,   0          ['block7a_bn[0][0]']
#  )                              1152)
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, None, None,   0           ['block7a_activation[0][0]',
#                                 1152)                             'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, None, None,   368640      ['block7a_se_excite[0][0]']
#                                 320)
#
#  block7a_project_bn (BatchNorma  (None, None, None,   1280       ['block7a_project_conv[0][0]']
#  lization)                      320)
#
#  top_conv (Conv2D)              (None, None, None,   409600      ['block7a_project_bn[0][0]']
#                                 1280)
#
#  top_bn (BatchNormalization)    (None, None, None,   5120        ['top_conv[0][0]']
#                                 1280)
#
#  top_activation (Activation)    (None, None, None,   0           ['top_bn[0][0]']
#                                 1280)
#
# ==================================================================================================
# Total params: 4,049,571
# Trainable params: 0
# Non-trainable params: 4,049,571
# __________________________________________________________________________________________________

# %%
# pretrained model의 category와 유사하지 않다고 생각하여 전체 레이어를 동결 후 학습

# top <- false 이기 때문에 concatenate까지 하고 모델은 종료
# flatten 대신 GlobalAveragePooling2D()

from tensorflow.keras import layers

flat_layer = layers.GlobalAveragePooling2D()(base_model.output)

output = layers.Dense(2, activation = 'softmax')(flat_layer)

import tensorflow as tf
model = tf.keras.models.Model(base_model.input, output)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling (Rescaling)          (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  normalization (Normalization)  (None, None, None,   7           ['rescaling[0][0]']
#                                 3)
#
#  tf.math.truediv (TFOpLambda)   (None, None, None,   0           ['normalization[0][0]']
#                                 3)
#
#  stem_conv_pad (ZeroPadding2D)  (None, None, None,   0           ['tf.math.truediv[0][0]']
#                                 3)
#
#  stem_conv (Conv2D)             (None, None, None,   864         ['stem_conv_pad[0][0]']
#                                 32)
#
#  stem_bn (BatchNormalization)   (None, None, None,   128         ['stem_conv[0][0]']
#                                 32)
#
#  stem_activation (Activation)   (None, None, None,   0           ['stem_bn[0][0]']
#                                 32)
#
#  block1a_dwconv (DepthwiseConv2  (None, None, None,   288        ['stem_activation[0][0]']
#  D)                             32)
#
#  block1a_bn (BatchNormalization  (None, None, None,   128        ['block1a_dwconv[0][0]']
#  )                              32)
#
#  block1a_activation (Activation  (None, None, None,   0          ['block1a_bn[0][0]']
#  )                              32)
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, None, None,   0           ['block1a_activation[0][0]',
#                                 32)                               'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, None, None,   512         ['block1a_se_excite[0][0]']
#                                 16)
#
#  block1a_project_bn (BatchNorma  (None, None, None,   64         ['block1a_project_conv[0][0]']
#  lization)                      16)
#
#  block2a_expand_conv (Conv2D)   (None, None, None,   1536        ['block1a_project_bn[0][0]']
#                                 96)
#
#  block2a_expand_bn (BatchNormal  (None, None, None,   384        ['block2a_expand_conv[0][0]']
#  ization)                       96)
#
#  block2a_expand_activation (Act  (None, None, None,   0          ['block2a_expand_bn[0][0]']
#  ivation)                       96)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block2a_expand_activation[0][0]
#  g2D)                           96)                              ']
#
#  block2a_dwconv (DepthwiseConv2  (None, None, None,   864        ['block2a_dwconv_pad[0][0]']
#  D)                             96)
#
#  block2a_bn (BatchNormalization  (None, None, None,   384        ['block2a_dwconv[0][0]']
#  )                              96)
#
#  block2a_activation (Activation  (None, None, None,   0          ['block2a_bn[0][0]']
#  )                              96)
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, None, None,   0           ['block2a_activation[0][0]',
#                                 96)                               'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, None, None,   2304        ['block2a_se_excite[0][0]']
#                                 24)
#
#  block2a_project_bn (BatchNorma  (None, None, None,   96         ['block2a_project_conv[0][0]']
#  lization)                      24)
#
#  block2b_expand_conv (Conv2D)   (None, None, None,   3456        ['block2a_project_bn[0][0]']
#                                 144)
#
#  block2b_expand_bn (BatchNormal  (None, None, None,   576        ['block2b_expand_conv[0][0]']
#  ization)                       144)
#
#  block2b_expand_activation (Act  (None, None, None,   0          ['block2b_expand_bn[0][0]']
#  ivation)                       144)
#
#  block2b_dwconv (DepthwiseConv2  (None, None, None,   1296       ['block2b_expand_activation[0][0]
#  D)                             144)                             ']
#
#  block2b_bn (BatchNormalization  (None, None, None,   576        ['block2b_dwconv[0][0]']
#  )                              144)
#
#  block2b_activation (Activation  (None, None, None,   0          ['block2b_bn[0][0]']
#  )                              144)
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, None, None,   0           ['block2b_activation[0][0]',
#                                 144)                              'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, None, None,   3456        ['block2b_se_excite[0][0]']
#                                 24)
#
#  block2b_project_bn (BatchNorma  (None, None, None,   96         ['block2b_project_conv[0][0]']
#  lization)                      24)
#
#  block2b_drop (Dropout)         (None, None, None,   0           ['block2b_project_bn[0][0]']
#                                 24)
#
#  block2b_add (Add)              (None, None, None,   0           ['block2b_drop[0][0]',
#                                 24)                               'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, None, None,   3456        ['block2b_add[0][0]']
#                                 144)
#
#  block3a_expand_bn (BatchNormal  (None, None, None,   576        ['block3a_expand_conv[0][0]']
#  ization)                       144)
#
#  block3a_expand_activation (Act  (None, None, None,   0          ['block3a_expand_bn[0][0]']
#  ivation)                       144)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block3a_expand_activation[0][0]
#  g2D)                           144)                             ']
#
#  block3a_dwconv (DepthwiseConv2  (None, None, None,   3600       ['block3a_dwconv_pad[0][0]']
#  D)                             144)
#
#  block3a_bn (BatchNormalization  (None, None, None,   576        ['block3a_dwconv[0][0]']
#  )                              144)
#
#  block3a_activation (Activation  (None, None, None,   0          ['block3a_bn[0][0]']
#  )                              144)
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, None, None,   0           ['block3a_activation[0][0]',
#                                 144)                              'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, None, None,   5760        ['block3a_se_excite[0][0]']
#                                 40)
#
#  block3a_project_bn (BatchNorma  (None, None, None,   160        ['block3a_project_conv[0][0]']
#  lization)                      40)
#
#  block3b_expand_conv (Conv2D)   (None, None, None,   9600        ['block3a_project_bn[0][0]']
#                                 240)
#
#  block3b_expand_bn (BatchNormal  (None, None, None,   960        ['block3b_expand_conv[0][0]']
#  ization)                       240)
#
#  block3b_expand_activation (Act  (None, None, None,   0          ['block3b_expand_bn[0][0]']
#  ivation)                       240)
#
#  block3b_dwconv (DepthwiseConv2  (None, None, None,   6000       ['block3b_expand_activation[0][0]
#  D)                             240)                             ']
#
#  block3b_bn (BatchNormalization  (None, None, None,   960        ['block3b_dwconv[0][0]']
#  )                              240)
#
#  block3b_activation (Activation  (None, None, None,   0          ['block3b_bn[0][0]']
#  )                              240)
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, None, None,   0           ['block3b_activation[0][0]',
#                                 240)                              'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, None, None,   9600        ['block3b_se_excite[0][0]']
#                                 40)
#
#  block3b_project_bn (BatchNorma  (None, None, None,   160        ['block3b_project_conv[0][0]']
#  lization)                      40)
#
#  block3b_drop (Dropout)         (None, None, None,   0           ['block3b_project_bn[0][0]']
#                                 40)
#
#  block3b_add (Add)              (None, None, None,   0           ['block3b_drop[0][0]',
#                                 40)                               'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, None, None,   9600        ['block3b_add[0][0]']
#                                 240)
#
#  block4a_expand_bn (BatchNormal  (None, None, None,   960        ['block4a_expand_conv[0][0]']
#  ization)                       240)
#
#  block4a_expand_activation (Act  (None, None, None,   0          ['block4a_expand_bn[0][0]']
#  ivation)                       240)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block4a_expand_activation[0][0]
#  g2D)                           240)                             ']
#
#  block4a_dwconv (DepthwiseConv2  (None, None, None,   2160       ['block4a_dwconv_pad[0][0]']
#  D)                             240)
#
#  block4a_bn (BatchNormalization  (None, None, None,   960        ['block4a_dwconv[0][0]']
#  )                              240)
#
#  block4a_activation (Activation  (None, None, None,   0          ['block4a_bn[0][0]']
#  )                              240)
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, None, None,   0           ['block4a_activation[0][0]',
#                                 240)                              'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, None, None,   19200       ['block4a_se_excite[0][0]']
#                                 80)
#
#  block4a_project_bn (BatchNorma  (None, None, None,   320        ['block4a_project_conv[0][0]']
#  lization)                      80)
#
#  block4b_expand_conv (Conv2D)   (None, None, None,   38400       ['block4a_project_bn[0][0]']
#                                 480)
#
#  block4b_expand_bn (BatchNormal  (None, None, None,   1920       ['block4b_expand_conv[0][0]']
#  ization)                       480)
#
#  block4b_expand_activation (Act  (None, None, None,   0          ['block4b_expand_bn[0][0]']
#  ivation)                       480)
#
#  block4b_dwconv (DepthwiseConv2  (None, None, None,   4320       ['block4b_expand_activation[0][0]
#  D)                             480)                             ']
#
#  block4b_bn (BatchNormalization  (None, None, None,   1920       ['block4b_dwconv[0][0]']
#  )                              480)
#
#  block4b_activation (Activation  (None, None, None,   0          ['block4b_bn[0][0]']
#  )                              480)
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, None, None,   0           ['block4b_activation[0][0]',
#                                 480)                              'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, None, None,   38400       ['block4b_se_excite[0][0]']
#                                 80)
#
#  block4b_project_bn (BatchNorma  (None, None, None,   320        ['block4b_project_conv[0][0]']
#  lization)                      80)
#
#  block4b_drop (Dropout)         (None, None, None,   0           ['block4b_project_bn[0][0]']
#                                 80)
#
#  block4b_add (Add)              (None, None, None,   0           ['block4b_drop[0][0]',
#                                 80)                               'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, None, None,   38400       ['block4b_add[0][0]']
#                                 480)
#
#  block4c_expand_bn (BatchNormal  (None, None, None,   1920       ['block4c_expand_conv[0][0]']
#  ization)                       480)
#
#  block4c_expand_activation (Act  (None, None, None,   0          ['block4c_expand_bn[0][0]']
#  ivation)                       480)
#
#  block4c_dwconv (DepthwiseConv2  (None, None, None,   4320       ['block4c_expand_activation[0][0]
#  D)                             480)                             ']
#
#  block4c_bn (BatchNormalization  (None, None, None,   1920       ['block4c_dwconv[0][0]']
#  )                              480)
#
#  block4c_activation (Activation  (None, None, None,   0          ['block4c_bn[0][0]']
#  )                              480)
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, None, None,   0           ['block4c_activation[0][0]',
#                                 480)                              'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, None, None,   38400       ['block4c_se_excite[0][0]']
#                                 80)
#
#  block4c_project_bn (BatchNorma  (None, None, None,   320        ['block4c_project_conv[0][0]']
#  lization)                      80)
#
#  block4c_drop (Dropout)         (None, None, None,   0           ['block4c_project_bn[0][0]']
#                                 80)
#
#  block4c_add (Add)              (None, None, None,   0           ['block4c_drop[0][0]',
#                                 80)                               'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, None, None,   38400       ['block4c_add[0][0]']
#                                 480)
#
#  block5a_expand_bn (BatchNormal  (None, None, None,   1920       ['block5a_expand_conv[0][0]']
#  ization)                       480)
#
#  block5a_expand_activation (Act  (None, None, None,   0          ['block5a_expand_bn[0][0]']
#  ivation)                       480)
#
#  block5a_dwconv (DepthwiseConv2  (None, None, None,   12000      ['block5a_expand_activation[0][0]
#  D)                             480)                             ']
#
#  block5a_bn (BatchNormalization  (None, None, None,   1920       ['block5a_dwconv[0][0]']
#  )                              480)
#
#  block5a_activation (Activation  (None, None, None,   0          ['block5a_bn[0][0]']
#  )                              480)
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, None, None,   0           ['block5a_activation[0][0]',
#                                 480)                              'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, None, None,   53760       ['block5a_se_excite[0][0]']
#                                 112)
#
#  block5a_project_bn (BatchNorma  (None, None, None,   448        ['block5a_project_conv[0][0]']
#  lization)                      112)
#
#  block5b_expand_conv (Conv2D)   (None, None, None,   75264       ['block5a_project_bn[0][0]']
#                                 672)
#
#  block5b_expand_bn (BatchNormal  (None, None, None,   2688       ['block5b_expand_conv[0][0]']
#  ization)                       672)
#
#  block5b_expand_activation (Act  (None, None, None,   0          ['block5b_expand_bn[0][0]']
#  ivation)                       672)
#
#  block5b_dwconv (DepthwiseConv2  (None, None, None,   16800      ['block5b_expand_activation[0][0]
#  D)                             672)                             ']
#
#  block5b_bn (BatchNormalization  (None, None, None,   2688       ['block5b_dwconv[0][0]']
#  )                              672)
#
#  block5b_activation (Activation  (None, None, None,   0          ['block5b_bn[0][0]']
#  )                              672)
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, None, None,   0           ['block5b_activation[0][0]',
#                                 672)                              'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, None, None,   75264       ['block5b_se_excite[0][0]']
#                                 112)
#
#  block5b_project_bn (BatchNorma  (None, None, None,   448        ['block5b_project_conv[0][0]']
#  lization)                      112)
#
#  block5b_drop (Dropout)         (None, None, None,   0           ['block5b_project_bn[0][0]']
#                                 112)
#
#  block5b_add (Add)              (None, None, None,   0           ['block5b_drop[0][0]',
#                                 112)                              'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, None, None,   75264       ['block5b_add[0][0]']
#                                 672)
#
#  block5c_expand_bn (BatchNormal  (None, None, None,   2688       ['block5c_expand_conv[0][0]']
#  ization)                       672)
#
#  block5c_expand_activation (Act  (None, None, None,   0          ['block5c_expand_bn[0][0]']
#  ivation)                       672)
#
#  block5c_dwconv (DepthwiseConv2  (None, None, None,   16800      ['block5c_expand_activation[0][0]
#  D)                             672)                             ']
#
#  block5c_bn (BatchNormalization  (None, None, None,   2688       ['block5c_dwconv[0][0]']
#  )                              672)
#
#  block5c_activation (Activation  (None, None, None,   0          ['block5c_bn[0][0]']
#  )                              672)
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, None, None,   0           ['block5c_activation[0][0]',
#                                 672)                              'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, None, None,   75264       ['block5c_se_excite[0][0]']
#                                 112)
#
#  block5c_project_bn (BatchNorma  (None, None, None,   448        ['block5c_project_conv[0][0]']
#  lization)                      112)
#
#  block5c_drop (Dropout)         (None, None, None,   0           ['block5c_project_bn[0][0]']
#                                 112)
#
#  block5c_add (Add)              (None, None, None,   0           ['block5c_drop[0][0]',
#                                 112)                              'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, None, None,   75264       ['block5c_add[0][0]']
#                                 672)
#
#  block6a_expand_bn (BatchNormal  (None, None, None,   2688       ['block6a_expand_conv[0][0]']
#  ization)                       672)
#
#  block6a_expand_activation (Act  (None, None, None,   0          ['block6a_expand_bn[0][0]']
#  ivation)                       672)
#
#  block6a_dwconv_pad (ZeroPaddin  (None, None, None,   0          ['block6a_expand_activation[0][0]
#  g2D)                           672)                             ']
#
#  block6a_dwconv (DepthwiseConv2  (None, None, None,   16800      ['block6a_dwconv_pad[0][0]']
#  D)                             672)
#
#  block6a_bn (BatchNormalization  (None, None, None,   2688       ['block6a_dwconv[0][0]']
#  )                              672)
#
#  block6a_activation (Activation  (None, None, None,   0          ['block6a_bn[0][0]']
#  )                              672)
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
# ...
#  agePooling2D)
#
#  block6b_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6b_se_squeeze[0][0]']
#
#  block6b_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multiply)   (None, None, None,   0           ['block6b_activation[0][0]',
#                                 1152)                             'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv2D)  (None, None, None,   221184      ['block6b_se_excite[0][0]']
#                                 192)
#
#  block6b_project_bn (BatchNorma  (None, None, None,   768        ['block6b_project_conv[0][0]']
#  lization)                      192)
#
#  block6b_drop (Dropout)         (None, None, None,   0           ['block6b_project_bn[0][0]']
#                                 192)
#
#  block6b_add (Add)              (None, None, None,   0           ['block6b_drop[0][0]',
#                                 192)                              'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, None, None,   221184      ['block6b_add[0][0]']
#                                 1152)
#
#  block6c_expand_bn (BatchNormal  (None, None, None,   4608       ['block6c_expand_conv[0][0]']
#  ization)                       1152)
#
#  block6c_expand_activation (Act  (None, None, None,   0          ['block6c_expand_bn[0][0]']
#  ivation)                       1152)
#
#  block6c_dwconv (DepthwiseConv2  (None, None, None,   28800      ['block6c_expand_activation[0][0]
#  D)                             1152)                            ']
#
#  block6c_bn (BatchNormalization  (None, None, None,   4608       ['block6c_dwconv[0][0]']
#  )                              1152)
#
#  block6c_activation (Activation  (None, None, None,   0          ['block6c_bn[0][0]']
#  )                              1152)
#
#  block6c_se_squeeze (GlobalAver  (None, 1152)        0           ['block6c_activation[0][0]']
#  agePooling2D)
#
#  block6c_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6c_se_squeeze[0][0]']
#
#  block6c_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multiply)   (None, None, None,   0           ['block6c_activation[0][0]',
#                                 1152)                             'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv2D)  (None, None, None,   221184      ['block6c_se_excite[0][0]']
#                                 192)
#
#  block6c_project_bn (BatchNorma  (None, None, None,   768        ['block6c_project_conv[0][0]']
#  lization)                      192)
#
#  block6c_drop (Dropout)         (None, None, None,   0           ['block6c_project_bn[0][0]']
#                                 192)
#
#  block6c_add (Add)              (None, None, None,   0           ['block6c_drop[0][0]',
#                                 192)                              'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2D)   (None, None, None,   221184      ['block6c_add[0][0]']
#                                 1152)
#
#  block6d_expand_bn (BatchNormal  (None, None, None,   4608       ['block6d_expand_conv[0][0]']
#  ization)                       1152)
#
#  block6d_expand_activation (Act  (None, None, None,   0          ['block6d_expand_bn[0][0]']
#  ivation)                       1152)
#
#  block6d_dwconv (DepthwiseConv2  (None, None, None,   28800      ['block6d_expand_activation[0][0]
#  D)                             1152)                            ']
#
#  block6d_bn (BatchNormalization  (None, None, None,   4608       ['block6d_dwconv[0][0]']
#  )                              1152)
#
#  block6d_activation (Activation  (None, None, None,   0          ['block6d_bn[0][0]']
#  )                              1152)
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, None, None,   0           ['block6d_activation[0][0]',
#                                 1152)                             'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, None, None,   221184      ['block6d_se_excite[0][0]']
#                                 192)
#
#  block6d_project_bn (BatchNorma  (None, None, None,   768        ['block6d_project_conv[0][0]']
#  lization)                      192)
#
#  block6d_drop (Dropout)         (None, None, None,   0           ['block6d_project_bn[0][0]']
#                                 192)
#
#  block6d_add (Add)              (None, None, None,   0           ['block6d_drop[0][0]',
#                                 192)                              'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, None, None,   221184      ['block6d_add[0][0]']
#                                 1152)
#
#  block7a_expand_bn (BatchNormal  (None, None, None,   4608       ['block7a_expand_conv[0][0]']
#  ization)                       1152)
#
#  block7a_expand_activation (Act  (None, None, None,   0          ['block7a_expand_bn[0][0]']
#  ivation)                       1152)
#
#  block7a_dwconv (DepthwiseConv2  (None, None, None,   10368      ['block7a_expand_activation[0][0]
#  D)                             1152)                            ']
#
#  block7a_bn (BatchNormalization  (None, None, None,   4608       ['block7a_dwconv[0][0]']
#  )                              1152)
#
#  block7a_activation (Activation  (None, None, None,   0          ['block7a_bn[0][0]']
#  )                              1152)
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, None, None,   0           ['block7a_activation[0][0]',
#                                 1152)                             'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, None, None,   368640      ['block7a_se_excite[0][0]']
#                                 320)
#
#  block7a_project_bn (BatchNorma  (None, None, None,   1280       ['block7a_project_conv[0][0]']
#  lization)                      320)
#
#  top_conv (Conv2D)              (None, None, None,   409600      ['block7a_project_bn[0][0]']
#                                 1280)
#
#  top_bn (BatchNormalization)    (None, None, None,   5120        ['top_conv[0][0]']
#                                 1280)
#
#  top_activation (Activation)    (None, None, None,   0           ['top_bn[0][0]']
#                                 1280)
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            2562        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 4,052,133
# Trainable params: 2,562
# Non-trainable params: 4,049,571
# __________________________________________________________________________________________________

# %%
saved_model = '/content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5'
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50,restore_best_weights=True)
mc = tf.keras.callbacks.ModelCheckpoint(saved_model, monitor='val_sparse_categorical_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
custom_adam = tf.keras.optimizers.Adam(learning_rate=0.001)

#fine tuning fit 

model.compile(optimizer=custom_adam, loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

history = model.fit(x_train, y_train, validation_data = (x_test, y_test), callbacks=[es, mc], epochs = 1000, batch_size = 64)
# Out:
# Epoch 1/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.6512 - sparse_categorical_accuracy: 0.6107
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.66341, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 20s 164ms/step - loss: 0.6512 - sparse_categorical_accuracy: 0.6107 - val_loss: 0.5931 - val_sparse_categorical_accuracy: 0.6634
# Epoch 2/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.5663 - sparse_categorical_accuracy: 0.7134
# Epoch 2: val_sparse_categorical_accuracy improved from 0.66341 to 0.73333, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 129ms/step - loss: 0.5663 - sparse_categorical_accuracy: 0.7134 - val_loss: 0.5462 - val_sparse_categorical_accuracy: 0.7333
# Epoch 3/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.5353 - sparse_categorical_accuracy: 0.7319
# Epoch 3: val_sparse_categorical_accuracy improved from 0.73333 to 0.74959, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 129ms/step - loss: 0.5353 - sparse_categorical_accuracy: 0.7319 - val_loss: 0.5255 - val_sparse_categorical_accuracy: 0.7496
# Epoch 4/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.5123 - sparse_categorical_accuracy: 0.7457
# Epoch 4: val_sparse_categorical_accuracy improved from 0.74959 to 0.76260, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 129ms/step - loss: 0.5123 - sparse_categorical_accuracy: 0.7457 - val_loss: 0.5102 - val_sparse_categorical_accuracy: 0.7626
# Epoch 5/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.5005 - sparse_categorical_accuracy: 0.7617
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.76260
# 77/77 [==============================] - 9s 122ms/step - loss: 0.5005 - sparse_categorical_accuracy: 0.7617 - val_loss: 0.5055 - val_sparse_categorical_accuracy: 0.7626
# Epoch 6/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4897 - sparse_categorical_accuracy: 0.7687
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.76260
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4897 - sparse_categorical_accuracy: 0.7687 - val_loss: 0.4958 - val_sparse_categorical_accuracy: 0.7626
# Epoch 7/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4839 - sparse_categorical_accuracy: 0.7699
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.76260
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4839 - sparse_categorical_accuracy: 0.7699 - val_loss: 0.4949 - val_sparse_categorical_accuracy: 0.7512
# Epoch 8/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4734 - sparse_categorical_accuracy: 0.7748
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.76260
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4734 - sparse_categorical_accuracy: 0.7748 - val_loss: 0.5091 - val_sparse_categorical_accuracy: 0.7220
# Epoch 9/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4706 - sparse_categorical_accuracy: 0.7811
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.76260
# 77/77 [==============================] - 9s 123ms/step - loss: 0.4706 - sparse_categorical_accuracy: 0.7811 - val_loss: 0.4831 - val_sparse_categorical_accuracy: 0.7610
# Epoch 10/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4588 - sparse_categorical_accuracy: 0.7849
# Epoch 10: val_sparse_categorical_accuracy improved from 0.76260 to 0.76911, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 136ms/step - loss: 0.4588 - sparse_categorical_accuracy: 0.7849 - val_loss: 0.4724 - val_sparse_categorical_accuracy: 0.7691
# Epoch 11/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4569 - sparse_categorical_accuracy: 0.7920
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.76911
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4569 - sparse_categorical_accuracy: 0.7920 - val_loss: 0.4840 - val_sparse_categorical_accuracy: 0.7659
# Epoch 12/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4529 - sparse_categorical_accuracy: 0.7894
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.76911
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4529 - sparse_categorical_accuracy: 0.7894 - val_loss: 0.4745 - val_sparse_categorical_accuracy: 0.7626
# Epoch 13/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4458 - sparse_categorical_accuracy: 0.7949
# Epoch 13: val_sparse_categorical_accuracy improved from 0.76911 to 0.77236, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 134ms/step - loss: 0.4458 - sparse_categorical_accuracy: 0.7949 - val_loss: 0.4658 - val_sparse_categorical_accuracy: 0.7724
# Epoch 14/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4469 - sparse_categorical_accuracy: 0.7945
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.77236
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4469 - sparse_categorical_accuracy: 0.7945 - val_loss: 0.4753 - val_sparse_categorical_accuracy: 0.7659
# Epoch 15/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4407 - sparse_categorical_accuracy: 0.7985
# Epoch 15: val_sparse_categorical_accuracy improved from 0.77236 to 0.77561, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 134ms/step - loss: 0.4407 - sparse_categorical_accuracy: 0.7985 - val_loss: 0.4586 - val_sparse_categorical_accuracy: 0.7756
# Epoch 16/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4343 - sparse_categorical_accuracy: 0.8085
# Epoch 16: val_sparse_categorical_accuracy improved from 0.77561 to 0.77724, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 129ms/step - loss: 0.4343 - sparse_categorical_accuracy: 0.8085 - val_loss: 0.4555 - val_sparse_categorical_accuracy: 0.7772
# Epoch 17/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4334 - sparse_categorical_accuracy: 0.8099
# Epoch 17: val_sparse_categorical_accuracy improved from 0.77724 to 0.78211, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 133ms/step - loss: 0.4334 - sparse_categorical_accuracy: 0.8099 - val_loss: 0.4538 - val_sparse_categorical_accuracy: 0.7821
# Epoch 18/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4340 - sparse_categorical_accuracy: 0.8065
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.78211
# 77/77 [==============================] - 9s 123ms/step - loss: 0.4340 - sparse_categorical_accuracy: 0.8065 - val_loss: 0.4489 - val_sparse_categorical_accuracy: 0.7821
# Epoch 19/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4311 - sparse_categorical_accuracy: 0.8081
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.78211
# 77/77 [==============================] - 9s 123ms/step - loss: 0.4311 - sparse_categorical_accuracy: 0.8081 - val_loss: 0.4498 - val_sparse_categorical_accuracy: 0.7821
# Epoch 20/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4300 - sparse_categorical_accuracy: 0.8065
# Epoch 20: val_sparse_categorical_accuracy improved from 0.78211 to 0.78699, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 11s 137ms/step - loss: 0.4300 - sparse_categorical_accuracy: 0.8065 - val_loss: 0.4447 - val_sparse_categorical_accuracy: 0.7870
# Epoch 21/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4326 - sparse_categorical_accuracy: 0.7959
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.78699
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4326 - sparse_categorical_accuracy: 0.7959 - val_loss: 0.4708 - val_sparse_categorical_accuracy: 0.7659
# Epoch 22/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4302 - sparse_categorical_accuracy: 0.8036
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.78699
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4302 - sparse_categorical_accuracy: 0.8036 - val_loss: 0.4625 - val_sparse_categorical_accuracy: 0.7740
# Epoch 23/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4228 - sparse_categorical_accuracy: 0.8036
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.78699
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4228 - sparse_categorical_accuracy: 0.8036 - val_loss: 0.4444 - val_sparse_categorical_accuracy: 0.7821
# Epoch 24/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4243 - sparse_categorical_accuracy: 0.8118
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.78699
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4243 - sparse_categorical_accuracy: 0.8118 - val_loss: 0.4512 - val_sparse_categorical_accuracy: 0.7821
# Epoch 25/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4212 - sparse_categorical_accuracy: 0.8050
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.78699
# 77/77 [==============================] - 9s 123ms/step - loss: 0.4212 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.4401 - val_sparse_categorical_accuracy: 0.7870
# Epoch 26/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4146 - sparse_categorical_accuracy: 0.8122
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.78699
# 77/77 [==============================] - 10s 126ms/step - loss: 0.4146 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.4454 - val_sparse_categorical_accuracy: 0.7805
# Epoch 27/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4147 - sparse_categorical_accuracy: 0.8111
# Epoch 27: val_sparse_categorical_accuracy improved from 0.78699 to 0.78862, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 11s 140ms/step - loss: 0.4147 - sparse_categorical_accuracy: 0.8111 - val_loss: 0.4360 - val_sparse_categorical_accuracy: 0.7886
# Epoch 28/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4165 - sparse_categorical_accuracy: 0.8111
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.78862
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4165 - sparse_categorical_accuracy: 0.8111 - val_loss: 0.4367 - val_sparse_categorical_accuracy: 0.7886
# Epoch 29/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4136 - sparse_categorical_accuracy: 0.8113
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.78862
# 77/77 [==============================] - 9s 123ms/step - loss: 0.4136 - sparse_categorical_accuracy: 0.8113 - val_loss: 0.4363 - val_sparse_categorical_accuracy: 0.7886
# Epoch 30/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4069 - sparse_categorical_accuracy: 0.8187
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.78862
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4069 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.4417 - val_sparse_categorical_accuracy: 0.7870
# Epoch 31/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4096 - sparse_categorical_accuracy: 0.8087
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.78862
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4096 - sparse_categorical_accuracy: 0.8087 - val_loss: 0.4389 - val_sparse_categorical_accuracy: 0.7854
# Epoch 32/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4158 - sparse_categorical_accuracy: 0.8103
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.78862
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4158 - sparse_categorical_accuracy: 0.8103 - val_loss: 0.4367 - val_sparse_categorical_accuracy: 0.7870
# Epoch 33/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4118 - sparse_categorical_accuracy: 0.8132
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.78862
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4118 - sparse_categorical_accuracy: 0.8132 - val_loss: 0.4374 - val_sparse_categorical_accuracy: 0.7854
# Epoch 34/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4051 - sparse_categorical_accuracy: 0.8242
# Epoch 34: val_sparse_categorical_accuracy improved from 0.78862 to 0.79350, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 135ms/step - loss: 0.4051 - sparse_categorical_accuracy: 0.8242 - val_loss: 0.4321 - val_sparse_categorical_accuracy: 0.7935
# Epoch 35/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4105 - sparse_categorical_accuracy: 0.8187
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.79350
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4105 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.4325 - val_sparse_categorical_accuracy: 0.7854
# Epoch 36/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4015 - sparse_categorical_accuracy: 0.8207
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.79350
# 77/77 [==============================] - 9s 121ms/step - loss: 0.4015 - sparse_categorical_accuracy: 0.8207 - val_loss: 0.4608 - val_sparse_categorical_accuracy: 0.7821
# Epoch 37/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4107 - sparse_categorical_accuracy: 0.8111
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.79350
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4107 - sparse_categorical_accuracy: 0.8111 - val_loss: 0.4325 - val_sparse_categorical_accuracy: 0.7919
# Epoch 38/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4042 - sparse_categorical_accuracy: 0.8154
# Epoch 38: val_sparse_categorical_accuracy improved from 0.79350 to 0.80000, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 136ms/step - loss: 0.4042 - sparse_categorical_accuracy: 0.8154 - val_loss: 0.4308 - val_sparse_categorical_accuracy: 0.8000
# Epoch 39/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3958 - sparse_categorical_accuracy: 0.8227
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.80000
# 77/77 [==============================] - 9s 121ms/step - loss: 0.3958 - sparse_categorical_accuracy: 0.8227 - val_loss: 0.4359 - val_sparse_categorical_accuracy: 0.7967
# Epoch 40/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3952 - sparse_categorical_accuracy: 0.8239
# Epoch 40: val_sparse_categorical_accuracy improved from 0.80000 to 0.80163, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 11s 143ms/step - loss: 0.3952 - sparse_categorical_accuracy: 0.8239 - val_loss: 0.4332 - val_sparse_categorical_accuracy: 0.8016
# Epoch 41/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4035 - sparse_categorical_accuracy: 0.8130
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.80163
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4035 - sparse_categorical_accuracy: 0.8130 - val_loss: 0.4388 - val_sparse_categorical_accuracy: 0.8016
# Epoch 42/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3913 - sparse_categorical_accuracy: 0.8221
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.80163
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3913 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.4291 - val_sparse_categorical_accuracy: 0.7870
# Epoch 43/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3940 - sparse_categorical_accuracy: 0.8209
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.80163
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3940 - sparse_categorical_accuracy: 0.8209 - val_loss: 0.4304 - val_sparse_categorical_accuracy: 0.7854
# Epoch 44/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3987 - sparse_categorical_accuracy: 0.8195
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.80163
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3987 - sparse_categorical_accuracy: 0.8195 - val_loss: 0.4282 - val_sparse_categorical_accuracy: 0.7951
# Epoch 45/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3943 - sparse_categorical_accuracy: 0.8219
# Epoch 45: val_sparse_categorical_accuracy improved from 0.80163 to 0.80488, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 11s 141ms/step - loss: 0.3943 - sparse_categorical_accuracy: 0.8219 - val_loss: 0.4275 - val_sparse_categorical_accuracy: 0.8049
# Epoch 46/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3899 - sparse_categorical_accuracy: 0.8235
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.80488
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3899 - sparse_categorical_accuracy: 0.8235 - val_loss: 0.4492 - val_sparse_categorical_accuracy: 0.7902
# Epoch 47/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3893 - sparse_categorical_accuracy: 0.8274
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.80488
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3893 - sparse_categorical_accuracy: 0.8274 - val_loss: 0.4288 - val_sparse_categorical_accuracy: 0.7886
# Epoch 48/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3932 - sparse_categorical_accuracy: 0.8221
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.80488
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3932 - sparse_categorical_accuracy: 0.8221 - val_loss: 0.4317 - val_sparse_categorical_accuracy: 0.8033
# Epoch 49/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3932 - sparse_categorical_accuracy: 0.8217
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.80488
# 77/77 [==============================] - 10s 125ms/step - loss: 0.3932 - sparse_categorical_accuracy: 0.8217 - val_loss: 0.4268 - val_sparse_categorical_accuracy: 0.7935
# Epoch 50/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.4007 - sparse_categorical_accuracy: 0.8166
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.80488
# 77/77 [==============================] - 9s 122ms/step - loss: 0.4007 - sparse_categorical_accuracy: 0.8166 - val_loss: 0.4458 - val_sparse_categorical_accuracy: 0.7821
# Epoch 51/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3892 - sparse_categorical_accuracy: 0.8292
# Epoch 51: val_sparse_categorical_accuracy improved from 0.80488 to 0.80650, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 11s 138ms/step - loss: 0.3892 - sparse_categorical_accuracy: 0.8292 - val_loss: 0.4278 - val_sparse_categorical_accuracy: 0.8065
# Epoch 52/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3911 - sparse_categorical_accuracy: 0.8246
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3911 - sparse_categorical_accuracy: 0.8246 - val_loss: 0.4298 - val_sparse_categorical_accuracy: 0.8033
# Epoch 53/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3888 - sparse_categorical_accuracy: 0.8274
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3888 - sparse_categorical_accuracy: 0.8274 - val_loss: 0.4279 - val_sparse_categorical_accuracy: 0.7870
# Epoch 54/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3870 - sparse_categorical_accuracy: 0.8242
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3870 - sparse_categorical_accuracy: 0.8242 - val_loss: 0.4250 - val_sparse_categorical_accuracy: 0.7967
# Epoch 55/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3846 - sparse_categorical_accuracy: 0.8294
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3846 - sparse_categorical_accuracy: 0.8294 - val_loss: 0.4262 - val_sparse_categorical_accuracy: 0.7951
# Epoch 56/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3886 - sparse_categorical_accuracy: 0.8187
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3886 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.4445 - val_sparse_categorical_accuracy: 0.7984
# Epoch 57/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3877 - sparse_categorical_accuracy: 0.8268
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3877 - sparse_categorical_accuracy: 0.8268 - val_loss: 0.4324 - val_sparse_categorical_accuracy: 0.8033
# Epoch 58/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3827 - sparse_categorical_accuracy: 0.8307
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3827 - sparse_categorical_accuracy: 0.8307 - val_loss: 0.4402 - val_sparse_categorical_accuracy: 0.7951
# Epoch 59/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3854 - sparse_categorical_accuracy: 0.8276
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3854 - sparse_categorical_accuracy: 0.8276 - val_loss: 0.4297 - val_sparse_categorical_accuracy: 0.8033
# Epoch 60/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3823 - sparse_categorical_accuracy: 0.8284
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3823 - sparse_categorical_accuracy: 0.8284 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.7935
# Epoch 61/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3897 - sparse_categorical_accuracy: 0.8199
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3897 - sparse_categorical_accuracy: 0.8199 - val_loss: 0.4237 - val_sparse_categorical_accuracy: 0.7886
# Epoch 62/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3801 - sparse_categorical_accuracy: 0.8278
# Epoch 62: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 124ms/step - loss: 0.3801 - sparse_categorical_accuracy: 0.8278 - val_loss: 0.4223 - val_sparse_categorical_accuracy: 0.7935
# Epoch 63/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3778 - sparse_categorical_accuracy: 0.8331
# Epoch 63: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8331 - val_loss: 0.4239 - val_sparse_categorical_accuracy: 0.7951
# Epoch 64/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3819 - sparse_categorical_accuracy: 0.8290
# Epoch 64: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3819 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.4266 - val_sparse_categorical_accuracy: 0.7984
# Epoch 65/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3748 - sparse_categorical_accuracy: 0.8333
# Epoch 65: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3748 - sparse_categorical_accuracy: 0.8333 - val_loss: 0.4234 - val_sparse_categorical_accuracy: 0.7967
# Epoch 66/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3754 - sparse_categorical_accuracy: 0.8347
# Epoch 66: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3754 - sparse_categorical_accuracy: 0.8347 - val_loss: 0.4269 - val_sparse_categorical_accuracy: 0.7951
# Epoch 67/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3812 - sparse_categorical_accuracy: 0.8307
# Epoch 67: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3812 - sparse_categorical_accuracy: 0.8307 - val_loss: 0.4385 - val_sparse_categorical_accuracy: 0.7967
# Epoch 68/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3810 - sparse_categorical_accuracy: 0.8288
# Epoch 68: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 10s 126ms/step - loss: 0.3810 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.7967
# Epoch 69/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3772 - sparse_categorical_accuracy: 0.8333
# Epoch 69: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3772 - sparse_categorical_accuracy: 0.8333 - val_loss: 0.4317 - val_sparse_categorical_accuracy: 0.8033
# Epoch 70/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3778 - sparse_categorical_accuracy: 0.8333
# Epoch 70: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8333 - val_loss: 0.4266 - val_sparse_categorical_accuracy: 0.8065
# Epoch 71/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3742 - sparse_categorical_accuracy: 0.8335
# Epoch 71: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3742 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.4414 - val_sparse_categorical_accuracy: 0.7935
# Epoch 72/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3791 - sparse_categorical_accuracy: 0.8305
# Epoch 72: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3791 - sparse_categorical_accuracy: 0.8305 - val_loss: 0.4386 - val_sparse_categorical_accuracy: 0.7951
# Epoch 73/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3780 - sparse_categorical_accuracy: 0.8307
# Epoch 73: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 10s 126ms/step - loss: 0.3780 - sparse_categorical_accuracy: 0.8307 - val_loss: 0.4231 - val_sparse_categorical_accuracy: 0.8016
# Epoch 74/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3765 - sparse_categorical_accuracy: 0.8327
# Epoch 74: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3765 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.4262 - val_sparse_categorical_accuracy: 0.7967
# Epoch 75/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3778 - sparse_categorical_accuracy: 0.8325
# Epoch 75: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8325 - val_loss: 0.4275 - val_sparse_categorical_accuracy: 0.7967
# Epoch 76/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3704 - sparse_categorical_accuracy: 0.8396
# Epoch 76: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 10s 127ms/step - loss: 0.3704 - sparse_categorical_accuracy: 0.8396 - val_loss: 0.4235 - val_sparse_categorical_accuracy: 0.8000
# Epoch 77/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3773 - sparse_categorical_accuracy: 0.8250
# Epoch 77: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 10s 127ms/step - loss: 0.3773 - sparse_categorical_accuracy: 0.8250 - val_loss: 0.4253 - val_sparse_categorical_accuracy: 0.7951
# Epoch 78/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3790 - sparse_categorical_accuracy: 0.8298
# Epoch 78: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3790 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.4399 - val_sparse_categorical_accuracy: 0.7967
# Epoch 79/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3705 - sparse_categorical_accuracy: 0.8349
# Epoch 79: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3705 - sparse_categorical_accuracy: 0.8349 - val_loss: 0.4256 - val_sparse_categorical_accuracy: 0.7967
# Epoch 80/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3783 - sparse_categorical_accuracy: 0.8309
# Epoch 80: val_sparse_categorical_accuracy did not improve from 0.80650
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3783 - sparse_categorical_accuracy: 0.8309 - val_loss: 0.4223 - val_sparse_categorical_accuracy: 0.7935
# Epoch 81/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3750 - sparse_categorical_accuracy: 0.8349
# Epoch 81: val_sparse_categorical_accuracy improved from 0.80650 to 0.80976, saving model to /content/drive/MyDrive/팀 프로젝트/흉부_xray/Ch01_1.h5
# 77/77 [==============================] - 10s 135ms/step - loss: 0.3750 - sparse_categorical_accuracy: 0.8349 - val_loss: 0.4238 - val_sparse_categorical_accuracy: 0.8098
# Epoch 82/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3691 - sparse_categorical_accuracy: 0.8355
# Epoch 82: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3691 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.4197 - val_sparse_categorical_accuracy: 0.7984
# Epoch 83/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3676 - sparse_categorical_accuracy: 0.8380
# Epoch 83: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3676 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.4286 - val_sparse_categorical_accuracy: 0.7984
# Epoch 84/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3747 - sparse_categorical_accuracy: 0.8323
# Epoch 84: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3747 - sparse_categorical_accuracy: 0.8323 - val_loss: 0.4207 - val_sparse_categorical_accuracy: 0.8000
# Epoch 85/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3704 - sparse_categorical_accuracy: 0.8366
# Epoch 85: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3704 - sparse_categorical_accuracy: 0.8366 - val_loss: 0.4263 - val_sparse_categorical_accuracy: 0.8049
# Epoch 86/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3727 - sparse_categorical_accuracy: 0.8376
# Epoch 86: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3727 - sparse_categorical_accuracy: 0.8376 - val_loss: 0.4287 - val_sparse_categorical_accuracy: 0.8033
# Epoch 87/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3640 - sparse_categorical_accuracy: 0.8449
# Epoch 87: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 122ms/step - loss: 0.3640 - sparse_categorical_accuracy: 0.8449 - val_loss: 0.4222 - val_sparse_categorical_accuracy: 0.7967
# Epoch 88/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3664 - sparse_categorical_accuracy: 0.8355
# Epoch 88: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3664 - sparse_categorical_accuracy: 0.8355 - val_loss: 0.4251 - val_sparse_categorical_accuracy: 0.8016
# Epoch 89/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3717 - sparse_categorical_accuracy: 0.8331
# Epoch 89: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 128ms/step - loss: 0.3717 - sparse_categorical_accuracy: 0.8331 - val_loss: 0.4263 - val_sparse_categorical_accuracy: 0.8049
# Epoch 90/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3720 - sparse_categorical_accuracy: 0.8323
# Epoch 90: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3720 - sparse_categorical_accuracy: 0.8323 - val_loss: 0.4222 - val_sparse_categorical_accuracy: 0.7951
# Epoch 91/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3692 - sparse_categorical_accuracy: 0.8388
# Epoch 91: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3692 - sparse_categorical_accuracy: 0.8388 - val_loss: 0.4222 - val_sparse_categorical_accuracy: 0.7967
# Epoch 92/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3764 - sparse_categorical_accuracy: 0.8327
# Epoch 92: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3764 - sparse_categorical_accuracy: 0.8327 - val_loss: 0.4215 - val_sparse_categorical_accuracy: 0.7967
# Epoch 93/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3667 - sparse_categorical_accuracy: 0.8388
# Epoch 93: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3667 - sparse_categorical_accuracy: 0.8388 - val_loss: 0.4214 - val_sparse_categorical_accuracy: 0.7919
# Epoch 94/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3674 - sparse_categorical_accuracy: 0.8359
# Epoch 94: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3674 - sparse_categorical_accuracy: 0.8359 - val_loss: 0.4321 - val_sparse_categorical_accuracy: 0.7984
# Epoch 95/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3690 - sparse_categorical_accuracy: 0.8351
# Epoch 95: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3690 - sparse_categorical_accuracy: 0.8351 - val_loss: 0.4252 - val_sparse_categorical_accuracy: 0.8000
# Epoch 96/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3735 - sparse_categorical_accuracy: 0.8361
# Epoch 96: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3735 - sparse_categorical_accuracy: 0.8361 - val_loss: 0.4233 - val_sparse_categorical_accuracy: 0.7935
# Epoch 97/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3672 - sparse_categorical_accuracy: 0.8378
# Epoch 97: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3672 - sparse_categorical_accuracy: 0.8378 - val_loss: 0.4407 - val_sparse_categorical_accuracy: 0.7854
# Epoch 98/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3634 - sparse_categorical_accuracy: 0.8368
# Epoch 98: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3634 - sparse_categorical_accuracy: 0.8368 - val_loss: 0.4302 - val_sparse_categorical_accuracy: 0.8000
# Epoch 99/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3680 - sparse_categorical_accuracy: 0.8378
# Epoch 99: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3680 - sparse_categorical_accuracy: 0.8378 - val_loss: 0.4312 - val_sparse_categorical_accuracy: 0.8016
# Epoch 100/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3694 - sparse_categorical_accuracy: 0.8359
# Epoch 100: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3694 - sparse_categorical_accuracy: 0.8359 - val_loss: 0.4275 - val_sparse_categorical_accuracy: 0.8098
# Epoch 101/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3665 - sparse_categorical_accuracy: 0.8341
# Epoch 101: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 124ms/step - loss: 0.3665 - sparse_categorical_accuracy: 0.8341 - val_loss: 0.4221 - val_sparse_categorical_accuracy: 0.7902
# Epoch 102/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3634 - sparse_categorical_accuracy: 0.8331
# Epoch 102: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 124ms/step - loss: 0.3634 - sparse_categorical_accuracy: 0.8331 - val_loss: 0.4278 - val_sparse_categorical_accuracy: 0.7967
# Epoch 103/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3648 - sparse_categorical_accuracy: 0.8380
# Epoch 103: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3648 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.4237 - val_sparse_categorical_accuracy: 0.7984
# Epoch 104/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3644 - sparse_categorical_accuracy: 0.8349
# Epoch 104: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3644 - sparse_categorical_accuracy: 0.8349 - val_loss: 0.4236 - val_sparse_categorical_accuracy: 0.7967
# Epoch 105/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3677 - sparse_categorical_accuracy: 0.8368
# Epoch 105: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3677 - sparse_categorical_accuracy: 0.8368 - val_loss: 0.4231 - val_sparse_categorical_accuracy: 0.7951
# Epoch 106/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3637 - sparse_categorical_accuracy: 0.8400
# Epoch 106: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3637 - sparse_categorical_accuracy: 0.8400 - val_loss: 0.4265 - val_sparse_categorical_accuracy: 0.8000
# Epoch 107/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3594 - sparse_categorical_accuracy: 0.8416
# Epoch 107: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3594 - sparse_categorical_accuracy: 0.8416 - val_loss: 0.4207 - val_sparse_categorical_accuracy: 0.8016
# Epoch 108/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3659 - sparse_categorical_accuracy: 0.8390
# Epoch 108: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3659 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.4246 - val_sparse_categorical_accuracy: 0.7967
# Epoch 109/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3646 - sparse_categorical_accuracy: 0.8408
# Epoch 109: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3646 - sparse_categorical_accuracy: 0.8408 - val_loss: 0.4364 - val_sparse_categorical_accuracy: 0.7935
# Epoch 110/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3667 - sparse_categorical_accuracy: 0.8410
# Epoch 110: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3667 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.4210 - val_sparse_categorical_accuracy: 0.7902
# Epoch 111/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3671 - sparse_categorical_accuracy: 0.8418
# Epoch 111: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 127ms/step - loss: 0.3671 - sparse_categorical_accuracy: 0.8418 - val_loss: 0.4210 - val_sparse_categorical_accuracy: 0.7919
# Epoch 112/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3623 - sparse_categorical_accuracy: 0.8396
# Epoch 112: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3623 - sparse_categorical_accuracy: 0.8396 - val_loss: 0.4245 - val_sparse_categorical_accuracy: 0.7967
# Epoch 113/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3652 - sparse_categorical_accuracy: 0.8398
# Epoch 113: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 124ms/step - loss: 0.3652 - sparse_categorical_accuracy: 0.8398 - val_loss: 0.4229 - val_sparse_categorical_accuracy: 0.8000
# Epoch 114/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3657 - sparse_categorical_accuracy: 0.8392
# Epoch 114: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3657 - sparse_categorical_accuracy: 0.8392 - val_loss: 0.4437 - val_sparse_categorical_accuracy: 0.7886
# Epoch 115/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3615 - sparse_categorical_accuracy: 0.8437
# Epoch 115: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3615 - sparse_categorical_accuracy: 0.8437 - val_loss: 0.4229 - val_sparse_categorical_accuracy: 0.8049
# Epoch 116/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3574 - sparse_categorical_accuracy: 0.8435
# Epoch 116: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 127ms/step - loss: 0.3574 - sparse_categorical_accuracy: 0.8435 - val_loss: 0.4253 - val_sparse_categorical_accuracy: 0.8033
# Epoch 117/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3552 - sparse_categorical_accuracy: 0.8449
# Epoch 117: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3552 - sparse_categorical_accuracy: 0.8449 - val_loss: 0.4265 - val_sparse_categorical_accuracy: 0.7984
# Epoch 118/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3595 - sparse_categorical_accuracy: 0.8408
# Epoch 118: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3595 - sparse_categorical_accuracy: 0.8408 - val_loss: 0.4583 - val_sparse_categorical_accuracy: 0.7837
# Epoch 119/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3598 - sparse_categorical_accuracy: 0.8376
# Epoch 119: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3598 - sparse_categorical_accuracy: 0.8376 - val_loss: 0.4334 - val_sparse_categorical_accuracy: 0.8065
# Epoch 120/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3602 - sparse_categorical_accuracy: 0.8404
# Epoch 120: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3602 - sparse_categorical_accuracy: 0.8404 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.7951
# Epoch 121/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3532 - sparse_categorical_accuracy: 0.8465
# Epoch 121: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3532 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.4265 - val_sparse_categorical_accuracy: 0.7951
# Epoch 122/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3557 - sparse_categorical_accuracy: 0.8439
# Epoch 122: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3557 - sparse_categorical_accuracy: 0.8439 - val_loss: 0.4368 - val_sparse_categorical_accuracy: 0.8000
# Epoch 123/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3599 - sparse_categorical_accuracy: 0.8396
# Epoch 123: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3599 - sparse_categorical_accuracy: 0.8396 - val_loss: 0.4276 - val_sparse_categorical_accuracy: 0.8016
# Epoch 124/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3544 - sparse_categorical_accuracy: 0.8441
# Epoch 124: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3544 - sparse_categorical_accuracy: 0.8441 - val_loss: 0.4248 - val_sparse_categorical_accuracy: 0.8000
# Epoch 125/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3616 - sparse_categorical_accuracy: 0.8347
# Epoch 125: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 123ms/step - loss: 0.3616 - sparse_categorical_accuracy: 0.8347 - val_loss: 0.4301 - val_sparse_categorical_accuracy: 0.7919
# Epoch 126/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3570 - sparse_categorical_accuracy: 0.8459
# Epoch 126: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3570 - sparse_categorical_accuracy: 0.8459 - val_loss: 0.4233 - val_sparse_categorical_accuracy: 0.8065
# Epoch 127/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3544 - sparse_categorical_accuracy: 0.8433
# Epoch 127: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 9s 124ms/step - loss: 0.3544 - sparse_categorical_accuracy: 0.8433 - val_loss: 0.4242 - val_sparse_categorical_accuracy: 0.8016
# Epoch 128/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3609 - sparse_categorical_accuracy: 0.8420
# Epoch 128: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 127ms/step - loss: 0.3609 - sparse_categorical_accuracy: 0.8420 - val_loss: 0.4301 - val_sparse_categorical_accuracy: 0.7935
# Epoch 129/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3526 - sparse_categorical_accuracy: 0.8463
# Epoch 129: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 124ms/step - loss: 0.3526 - sparse_categorical_accuracy: 0.8463 - val_loss: 0.4313 - val_sparse_categorical_accuracy: 0.7919
# Epoch 130/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3569 - sparse_categorical_accuracy: 0.8390
# Epoch 130: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 125ms/step - loss: 0.3569 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.4254 - val_sparse_categorical_accuracy: 0.7935
# Epoch 131/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3525 - sparse_categorical_accuracy: 0.8467
# Epoch 131: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 127ms/step - loss: 0.3525 - sparse_categorical_accuracy: 0.8467 - val_loss: 0.4360 - val_sparse_categorical_accuracy: 0.7951
# Epoch 132/1000
# 77/77 [==============================] - ETA: 0s - loss: 0.3597 - sparse_categorical_accuracy: 0.8390Restoring model weights from the end of the best epoch: 82.
#
# Epoch 132: val_sparse_categorical_accuracy did not improve from 0.80976
# 77/77 [==============================] - 10s 125ms/step - loss: 0.3597 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.4258 - val_sparse_categorical_accuracy: 0.8098
# Epoch 132: early stopping

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['sparse_categorical_accuracy'], label = 'train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
plt.legend()

# %%
plt.plot(history.history['loss'], label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()

# %%
model.evaluate(x_valid, y_valid)
# Out:
# 20/20 [==============================] - 2s 77ms/step - loss: 0.4350 - sparse_categorical_accuracy: 0.8211
# [0.4350433051586151, 0.8211382031440735]
